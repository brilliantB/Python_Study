# %% [markdown]
# # 2021 LG vs 두산 타자 기록

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
# 파일 읽어오기
data = '2021LG두산타자기록.xlsx'
d01 = pd.read_excel(data)
d01
# Out:
#     순위  선수명  팀명     타율  경기수   타석   타수   득점  1루타  2루타  3루타  홈런   루타  타점  희생번트  \
# 0    1  홍창기  LG  0.328  144  651  524  103  172   26    2   4  214  52     0
# 1    2  이상호  LG  0.308   45   68   65    5   20    2    0   0   22  12     2
# 2    3  한석현  LG  0.286   16   26   21    5    6    2    1   0   10   1     0
# 3    4  김현수  LG  0.285  140  595  506   70  144   23    1  17  220  96     0
# 4    5  채은성  LG  0.276  110  448  387   59  107   20    0  16  175  82     0
# 5    6  오지환  LG  0.254  134  532  464   62  118   19    2   8  165  57     4
# 6    7  서건창  LG  0.253  144  600  513   78  130   24    2   6  176  52     5
# 7    8  유강남  LG  0.252  130  441  397   39  100   16    0  11  149  60     3
# 8    9  이재원  LG  0.247   62  171  154   22   38    6    0   5   59  17     0
# 9   10  라모스  LG  0.243   51  205  185   14   45    7    1   8   78  25     0
# 10  10  이영빈  LG  0.243   72  169  148   21   36    9    0   2   51  16     2
# ...

# %%
d01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순위      30 non-null     int64
#  1   선수명     30 non-null     object
#  2   팀명      30 non-null     object
#  3   타율      30 non-null     object
#  4   경기수     30 non-null     int64
#  5   타석      30 non-null     int64
#  6   타수      30 non-null     int64
#  7   득점      30 non-null     int64
#  8   1루타     30 non-null     int64
#  9   2루타     30 non-null     int64
#  10  3루타     30 non-null     int64
#  11  홈런      30 non-null     int64
#  12  루타      30 non-null     int64
#  13  타점      30 non-null     int64
#  14  희생번트    30 non-null     int64
#  15  희생플라이   30 non-null     int64
# dtypes: int64(13), object(3)
# memory usage: 3.9+ KB

# %%
height = d01['홈런'].mean()
print('평균값 : ', height)
# Out:
# 평균값 :  3.8

# %%
d01_1 = d01['타율'].replace('-', np.nan)
d01_1
# Out:
# 0     0.328
# 1     0.308
# 2     0.286
# 3     0.285
# 4     0.276
# 5     0.254
# 6     0.253
# 7     0.252
# 8     0.247
# 9     0.243
# 10    0.243
# 11    0.238
# 12    0.230
# 13    0.228
# 14    0.222
# 15    0.218
# 16    0.212
# 17    0.199
# 18    0.170
# 19    0.167
# 20    0.148
# 21    0.143
# 22    0.138
# 23    0.132
# 24    0.130
# 25    0.125
# 26    0.100
# 27      NaN
# 28      NaN
# 29      NaN
# Name: 타율, dtype: float64

# %%
d01['타율'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-9cdda04aeab1> in <module>
# ----> 1 d01['타율'].mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11116         )
#   11117         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 11118             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11119
#   11120         # pandas\core\generic.py:10924: error: Cannot assign to a method
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10724
#   10725     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10726         return self._stat_function(
# ...

# %%
d01['경기수'].median()
# Out:
# 60.0

# %%
d01.describe()
# Out:
#               순위         경기수          타석          타수          득점       1루타  \
# count  30.000000   30.000000   30.000000   30.000000   30.000000   30.0000
# mean   15.366667   66.700000  195.066667  167.133333   23.300000   42.0000
# std     8.664169   48.571419  209.460050  177.854209   26.767389   49.8349
# min     1.000000    1.000000    0.000000    0.000000    0.000000    0.0000
# 25%     8.250000   31.250000   26.250000   21.500000    4.250000    3.2500
# 50%    15.500000   60.000000  103.000000   89.500000   12.500000   19.0000
# 75%    22.750000  109.250000  317.000000  268.250000   34.250000   61.0000
# max    28.000000  144.000000  651.000000  524.000000  103.000000  172.0000
#
#              2루타        3루타         홈런          루타         타점       희생번트  \
# count  30.000000  30.000000  30.000000   30.000000  30.000000  30.000000
# mean    7.400000   0.400000   3.800000   61.600000  21.633333   1.766667
# ...
